# %% [markdown]
# # Market Demand Analysis

# %% [markdown]
# 1. Data processing

# %%
import pandas as pd
import plotly.express as px

# %%
data = pd.read_csv('/content/Workforce_Skills_Gap_Analysis.csv')

# %% [markdown]
# **Skill Demand Forecast:** Analyze the 'Skills Most in Demand' data to predict future workforce needs and guide the creation of future training initiatives.

# %%
# First, we need to make a copy of the data
df = data.copy()

# Let's filter for most recent years (2022 and 2023) to predict future trends
df = df[df['Year'].isin([2022, 2023])]

# Next, we calculate the total number of employees needing reskilling by skill and sort descending
df = df.groupby('Skills Most in Demand')['Employees Needing Reskilling (Thousands)'].sum().sort_values(ascending=False)

# Then we reset the index to return a DataFrame
df = df.reset_index()

df
# Out:
#            Skills Most in Demand  Employees Needing Reskilling (Thousands)
# 0  Sales and Customer Management                                      1484
# 1           Healthcare Expertise                                      1375
# 2                  Data Analysis                                       907
# 3                Cloud Computing                                       800
# 4             Project Management                                       652
# 5        AI and Machine Learning                                       444
# 6              Digital Marketing                                       428
# 7    Renewable Energy Technology                                       339
# 8                  Cybersecurity                                       232

# %%
fig = px.bar(df,
             x='Employees Needing Reskilling (Thousands)',
             y='Skills Most in Demand',
             color='Skills Most in Demand',
             title="Skill Demand Forecast",
             labels={'Employees Needing Reskilling (Thousands)': 'Employees (Thousands)',
                     'Skills Most in Demand': 'Skills'},
             template='plotly_dark')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f09c6dc1-f1cc-42af-8342-dc680a272297" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f09c6dc1-f1cc-42af-8342-dc680a272297")) {                    Plotly.newPlot(                        "f09c6dc1-f1cc-42af-8342-dc680a272297",                        [{"alignmentgroup":"True","hovertemplate":"Skills=%{y}\u003cbr\u003eEmployees (Thousands)=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sales and Customer Management","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Sales and Customer Management","offsetgroup":"Sales and Customer Management","orientation":"h","showlegend":true,"textposition":"auto","x":[1484],"xaxis":"x","y":["Sales and Customer Management"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skills=%{y}\u003cbr\u003eEmployees (Thousands)=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Healthcare Expertise","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Healthcare Expertise","offsetgroup":"Healthcare Expertise","orientation":"h","showlegend":true,"textposition":"auto","x":[1375],"xaxis":"x","y":["Healthcare Expertise"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skills=%{y}\u003cbr\u003eEmployees (Thousands)=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Data Analysis","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Data Analysis","offsetgroup":"Data Analysis","orientation":"h","showlegend":true,"textposition":"auto","x":[907],"xaxis":"x","y":["Data Analysis"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skills=%{y}\u003cbr\u003eEmployees (Thousands)=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cloud Computing","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Cloud Computing","offsetgroup":"Cloud Computing","orientation":"h","showlegend":true,"textposition":"auto","x":[800],"xaxis":"x","y":["Cloud Computing"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skills=%{y}\u003cbr\u003eEmployees (Thousands)=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Project Management","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Project Management","offsetgroup":"Project Management","orientation":"h","showlegend":true,"textposition":"auto","x":[652],"xaxis":"x","y":["Project Management"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skills=%{y}\u003cbr\u003eEmployees (Thousands)=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AI and Machine Learning","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"AI and Machine Learning","offsetgroup":"AI and Machine Learning","orientation":"h","showlegend":true,"textposition":"auto","x":[444],"xaxis":"x","y":["AI and Machine Learning"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skills=%{y}\u003cbr\u003eEmployees (Thousands)=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Digital Marketing","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Digital Marketing","offsetgroup":"Digital Marketing","orientation":"h","showlegend":true,"textposition":"auto","x":[428],"xaxis":"x","y":["Digital Marketing"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skills=%{y}\u003cbr\u003eEmployees (Thousands)=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Renewable Energy Technology","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Renewable Energy Technology","offsetgroup":"Renewable Energy Technology","orientation":"h","showlegend":true,"textposition":"auto","x":[339],"xaxis":"x","y":["Renewable Energy Technology"],"yaxis":"y","type":"bar"},{"alignmentgroup": ...

# %% [markdown]
# The data indicates a strong future demand in the following areas:
#
#
# Sales and Customer Management tops the list with 1484 thousand employees needing reskilling, suggesting a critical need for sales skills and customer handling capabilities.
#
# Healthcare Expertise is the second most demanded skill with 1375 thousand employees requiring reskilling, indicating a growing need in the healthcare industry.
#
# Data Analysis and Cloud Computing are also in high demand, with 907 and 800 thousand employees needing training, respectively, pointing towards the ongoing digital transformation in businesses.
#
# Lower on the list but still significant, AI and Machine Learning, and Cybersecurity indicate emerging tech fields where future workforce needs are likely to increase, with 444 and 232 thousand employees needing reskilling respectively.

# %%
df = data.copy()

# Convert 'Year' to datetime format
df['Year'] = pd.to_datetime(df['Year'], format='%Y')

# Filter data up to the current year
df = df[df['Year'] <= '2024']

# Calculate the total cost of training for each industry and country
df['Total Training Cost (USD)'] = df['Employees Needing Reskilling (Thousands)'] * df['Average Training Cost Per Employee (USD)'] * 1000

# Group by 'Country' and 'Industry' and calculate the sum of 'Employees Needing Reskilling (Thousands)'
# and 'Total Training Cost (USD)' and the average of 'Business Impact of Skill Shortage (USD Million)'
df = df.groupby(['Country', 'Industry']).agg({'Employees Needing Reskilling (Thousands)': 'sum',
                                              'Total Training Cost (USD)': 'sum',
                                              'Business Impact of Skill Shortage (USD Million)': 'mean'}).reset_index()

# Calculate the cost per employee needing reskilling
df['Cost Per Employee Needing Reskilling (USD)'] = df['Total Training Cost (USD)'] / (df['Employees Needing Reskilling (Thousands)'] * 1000)

# Sort by 'Total Training Cost (USD)' in descending order
df = df.sort_values('Total Training Cost (USD)', ascending=False)

df
# Out:
#       Country        Industry  Employees Needing Reskilling (Thousands)  \
# 24      India    Construction                                       578
# 35         UK          Retail                                       483
# 5      Brazil          Retail                                       554
# 6      Brazil  Transportation                                       444
# 23    Germany      Healthcare                                       847
# 30      Japan          Retail                                       573
# 13     Canada      Technology                                       643
# 16      China       Education                                       475
# 33         UK         Finance                                       787
# 34         UK   Manufacturing                                       466
# 37        USA   Manufacturing                                       335
# 22     France      Technology                                       378
# 29      Japan     Hospitality                                       530
# 12     Canada          Retail                                       752
# 21     France          Retail                                       398
# 36        USA    Construction                                       486
# 20     France     Hospitality                                       396
# 9      Canada          Energy                                       331
# 1   Australia         Finance                                       452
# 26      Japan          Energy                                       424
# 0   Australia       Education                                       346
# 32         UK       Education                                       183
# 14     Canada  Transportation                                       361
# 3   Australia          Retail                                       218
# 4      Brazil          Energy                                       284
# 7      Canada    Construction                                       232
# 28      Japan      Healthcare                                       239
# 18      China          Retail                                       141
# 15      China    Construction                                       139
# 39        USA      Technology                                       176
# 38        USA          Retail                                       142
# 10     Canada         Finance                                       438
# 8      Canada       Education                                       116
# 17      China          Energy                                       359
# 27      Japan         Finance                                       202
# 31      Japan      Technology                                       117
# 2   Australia   Manufacturing                                        78
# 25      India       Education                                       100
# 11     Canada      Healthcare                                       177
# 19     France          Energy                                        59
#
#     Total Training Cost (USD)  \
# 24                 2384929000
# 35                 2285556000
# 5                  2237168000
# 6                  2082360000
# 23                 2015510000
# 30                 1949886000
# 13                 1868472000
# 16                 1830175000
# 33                 1742534000
# 34                 1709288000
# 37                 1565790000
# 22                 1467177000
# 29                 1332898000
# 12                 1328000000
# 21                 1323748000
# 36                 1317546000
# 20                 1299672000
# 9                  1273357000
# 1                  1075760000
# 26                  875984000
# 0                   872612000
# 32                  780495000
# 14                  747270000
# 3                   719036000
# 4                   718236000
# 7                   695304000
# 28                  682823000
# 18                  643947000
# 15                  581437000
# 39                  556160000
# 38                  548404000
# 10                  528228000
# 8                   432796000
# 17                  389156000
# 27                  360570000
# 31                  348777000
# 2                   314652000
# 25                  285800000
# 11                  281430000
# 19                  180835000
#
#     Business Impact of Skill Shortage (USD Million)  \
# 24                                            76.50
# 35                                           150.00
# 5                                            102.00
# 6                                            147.00
# 23                                           130.50
# 30                                           116.25
# 13                                            40.50
# 16                                            43.50
# 33                                             8.25
# 34                                            51.00
# 37                                            51.00
# 22                                            99.00
# 29                                           139.50
# 12                                            37.50
# 21                                           105.00
# 36                                            12.00
# 20                                            54.00
# 9                                            150.00
# 1                                             46.50
# 26                                            30.00
# 0                                            144.00
# 32                                           147.00
# 14                                           150.00
# 3                                             45.75
# 4                                              7.50
# 7                                             73.50
# 28                                            25.50
# 18                                            39.00
# 15                                           112.50
# 39                                           142.50
# 38                                           135.00
# 10                                            84.00
# 8                                              9.00
# 17                                           108.00
# 27                                            19.50
# 31                                           147.00
# 2                                             16.50
# 25                                            49.50
# 11                                           130.50
# 19                                            25.50
#
#     Cost Per Employee Needing Reskilling (USD)
# 24                                 4126.174740
# 35                                 4732.000000
# 5                                  4038.209386
# 6                                  4690.000000
# 23                                 2379.586777
# 30                                 3402.942408
# 13                                 2905.866252
# 16                                 3853.000000
# 33                                 2214.147395
# 34                                 3668.000000
# 37                                 4674.000000
# 22                                 3881.420635
# 29                                 2514.901887
# 12                                 1765.957447
# 21                                 3326.000000
# 36                                 2711.000000
# 20                                 3282.000000
# 9                                  3847.000000
# 1                                  2380.000000
# 26                                 2066.000000
# 0                                  2522.000000
# 32                                 4265.000000
# 14                                 2070.000000
# 3                                  3298.330275
# 4                                  2529.000000
# 7                                  2997.000000
# 28                                 2857.000000
# 18                                 4567.000000
# 15                                 4183.000000
# 39                                 3160.000000
# 38                                 3862.000000
# 10                                 1206.000000
# 8                                  3731.000000
# 17                                 1084.000000
# 27                                 1785.000000
# 31                                 2981.000000
# 2                                  4034.000000
# 25                                 2858.000000
# 11                                 1590.000000
# 19                                 3065.000000

# %% [markdown]
# 2. Data visualization

# %%
fig = px.bar(df, x='Total Training Cost (USD)', y='Country', color='Industry',
             title='Total Training Cost by Industry and Country',
             labels={'Total Training Cost (USD)': 'Total Training Cost (USD)',
                     'Country': 'Country'},
             hover_data=['Employees Needing Reskilling (Thousands)',
                         'Business Impact of Skill Shortage (USD Million)',
                         'Cost Per Employee Needing Reskilling (USD)'],
             color_discrete_sequence=px.colors.qualitative.Bold,
             template='plotly_dark')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="cb081073-7f61-48e6-90de-f677384ea28d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cb081073-7f61-48e6-90de-f677384ea28d")) {                    Plotly.newPlot(                        "cb081073-7f61-48e6-90de-f677384ea28d",                        [{"alignmentgroup":"True","customdata":[[578.0,76.5,4126.174740484429],[486.0,12.0,2711.0],[232.0,73.5,2997.0],[139.0,112.5,4183.0]],"hovertemplate":"Industry=Construction\u003cbr\u003eTotal Training Cost (USD)=%{x}\u003cbr\u003eCountry=%{y}\u003cbr\u003eEmployees Needing Reskilling (Thousands)=%{customdata[0]}\u003cbr\u003eBusiness Impact of Skill Shortage (USD Million)=%{customdata[1]}\u003cbr\u003eCost Per Employee Needing Reskilling (USD)=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Construction","marker":{"color":"rgb(127, 60, 141)","pattern":{"shape":""}},"name":"Construction","offsetgroup":"Construction","orientation":"h","showlegend":true,"textposition":"auto","x":[2384929000,1317546000,695304000,581437000],"xaxis":"x","y":["India","USA","Canada","China"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[483.0,150.0,4732.0],[554.0,102.0,4038.2093862815886],[573.0,116.25,3402.942408376963],[752.0,37.5,1765.9574468085107],[398.0,105.0,3326.0],[218.0,45.75,3298.330275229358],[141.0,39.0,4567.0],[142.0,135.0,3862.0]],"hovertemplate":"Industry=Retail\u003cbr\u003eTotal Training Cost (USD)=%{x}\u003cbr\u003eCountry=%{y}\u003cbr\u003eEmployees Needing Reskilling (Thousands)=%{customdata[0]}\u003cbr\u003eBusiness Impact of Skill Shortage (USD Million)=%{customdata[1]}\u003cbr\u003eCost Per Employee Needing Reskilling (USD)=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Retail","marker":{"color":"rgb(17, 165, 121)","pattern":{"shape":""}},"name":"Retail","offsetgroup":"Retail","orientation":"h","showlegend":true,"textposition":"auto","x":[2285556000,2237168000,1949886000,1328000000,1323748000,719036000,643947000,548404000],"xaxis":"x","y":["UK","Brazil","Japan","Canada","France","Australia","China","USA"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[444.0,147.0,4690.0],[361.0,150.0,2070.0]],"hovertemplate":"Industry=Transportation\u003cbr\u003eTotal Training Cost (USD)=%{x}\u003cbr\u003eCountry=%{y}\u003cbr\u003eEmployees Needing Reskilling (Thousands)=%{customdata[0]}\u003cbr\u003eBusiness Impact of Skill Shortage (USD Million)=%{customdata[1]}\u003cbr\u003eCost Per Employee Needing Reskilling (USD)=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Transportation","marker":{"color":"rgb(57, 105, 172)","pattern":{"shape":""}},"name":"Transportation","offsetgroup":"Transportation","orientation":"h","showlegend":true,"textposition":"auto","x":[2082360000,747270000],"xaxis":"x","y":["Brazil","Canada"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[847.0,130.5,2379.586776859504],[239.0,25.5,2857.0],[177.0,130.5,1590.0]],"hovertemplate":"Industry=Healthcare\u003cbr\u003eTotal Training Cost (USD)=%{x}\u003cbr\u003eCountry=%{y}\u003cbr\u003eEmployees Needing Reskilling (Thousands)=%{customdata[0]}\u003cbr\u003eBusiness Impact of Skill Shortage (USD Million)=%{customdata[1]}\u003cbr\u003eCost Per Employee Needing Reskilling (USD)=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Healthcare","marker":{"color":"rgb(242, 183, 1)","pattern":{"shape":""}},"name":"Healthcare","offsetgroup":"Healthcare","orientation":"h","showlegend":true,"textposition":"auto","x":[2015510000,682823000,281430000],"xaxis":"x","y":["Germany","Japan","Canada"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[643.0,40.5,2905.866251944012],[3 ...

# %% [markdown]
# 3. Insights generation

# %% [markdown]
# The analytics task provides insights into the reskilling needs and associated costs across various industries and countries.
#
# * **Retail industry in the UK and Brazil** are facing significant reskilling needs with 483 thousand and 554 thousand employees respectively, costing over $2.2 billion each.
#
# * **Germany's Healthcare sector needs** to reskill 847 thousand employees, with a total training cost exceeding $2 billion.
#
#   Among countries, **India's Construction sector** has the highest demand for reskilling, with 578 thousand employees at a cost of about $2.4 billion.
#
# * **The Technology sector in the USA** needs to reskill 176 thousand employees which would cost about $556 million, indicating a high cost per employee for reskilling in this industry.
#
# These insights can guide resource allocation in training and development efforts.
